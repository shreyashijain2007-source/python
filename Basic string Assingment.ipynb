# %% [markdown]
# Q1. Take a string input from user and print a string?
#
#     INPUT- "User Name"
#
#     Output-
#
#     User Name

# %%
#WRITE Your code

# %% [markdown]
# Q2. Take a string input from user and Find length of string ?
#
#     INPUT - "Python Programming"
#
#     OUTPUT = 18

# %%
#WRITE Your code

# %% [markdown]
# Q3. Write a Python program to take a word from the user and print:
#
#     First character
#
#     Fourth character
#
#     Last character
#
#     INPUT - Computer
#
#     OUTPUT -  First character: C
#     Fourth character: p
#     Last character: r

# %%
#WRITE Your code

# %% [markdown]
# Q4. Write a Python program to take a string from the user and perform slicing.
#     Print:
#     - First 5 characters
#     - Characters from index 2 to 7
#     - Last 4 characters
#
#     INPUT - Programming
#
#     OUTPUT -
#
#     First 5 characters: Progr
#     Characters from index 2 to 7: ogramm
#     Last 4 characters: ming

# %%
#WRITE Your code

# %% [markdown]
# Q5. Write a Python program to take a string from the user and convert it into uppercase.
#
#     INPUT -  python
#
#     Uppercase string: PYTHON

# %%
#WRITE Your code

# %% [markdown]
# Q6. Write a Python program to take a string from the user and convert it into lowercase.
#
#     INPUT - PYTHON
#
#     OUTPUT - Lowercase string: python

# %%
#WRITE Your code

# %% [markdown]
# Q7. Write a Python program to take user name as input and print a welcome message.
#
#      INPUT - Rahul
#
#      OUTPUT - Welcome Rahul

# %%
#WRITE Your code

# %% [markdown]
# Q8. Write a Python program to take a string from the user and reverse it.
#
#      INPUT - Python
#
#      OUTPUT - nohtyP

# %%
#WRITE Your code

# %% [markdown]
# Q9. Write a Python program to take first name and last name from the user and join them.
#
#      INPUT -
#
#      Enter first name: AMIT
#      Enter last name: Gupta
#
#      OUTPUT -
#
#      Full name is: Nikhil Charpe

# %%
#WRITE Your code

# %% [markdown]
# Q10. Write a Python program to check whether a word exists in the string or not.
#
#       INPUT - Enter a sentence: Python is easy
#
#               Enter word to search: easy
#
#       OUTPUT - True

# %%
#WRITE Your code
